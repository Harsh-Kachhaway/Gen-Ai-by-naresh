# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
from PIL import Image

# %%
image = Image.open(r'C:\Users\harsh\Desktop\GenAi cource from Nerash\Images\random anime girl.png')

# %%
image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=197x271>

# %%
type(image)
# Out:
# PIL.PngImagePlugin.PngImageFile

# %%
Ani_arr = np.asarray(image)

# %%
Ani_arr
# Out:
# array([[[204, 210, 206, 255],
#         [204, 210, 206, 255],
#         [204, 210, 206, 255],
#         ...,
#         [204, 210, 206, 255],
#         [204, 210, 206, 255],
#         [204, 210, 206, 255]],
#
#        [[204, 210, 206, 255],
#         [204, 210, 206, 255],
#         [204, 210, 206, 255],
#         ...,
#         [204, 210, 206, 255],
#         [204, 210, 206, 255],
#         [204, 210, 206, 255]],
#
#        [[204, 210, 206, 255],
#         [204, 210, 206, 255],
#         [204, 210, 206, 255],
#         ...,
#         [204, 210, 206, 255],
#         [204, 210, 206, 255],
#         [204, 210, 206, 255]],
#
#        ...,
#
#        [[204, 210, 206, 255],
#         [204, 210, 206, 255],
#         [204, 210, 206, 255],
#         ...,
#         [204, 210, 206, 255],
#         [204, 210, 206, 255],
#         [204, 210, 206, 255]],
#
#        [[204, 210, 206, 255],
#         [204, 210, 206, 255],
#         [204, 210, 206, 255],
#         ...,
#         [204, 210, 206, 255],
# ...

# %%
plt.imshow(Ani_arr)
plt.show()

# %%
Ani_arr.shape
# Out:
# (271, 197, 4)

# %%
type(Ani_arr)
# Out:
# numpy.ndarray

# %%
image2 = Image.open(r'C:\Users\harsh\Desktop\GenAi cource from Nerash\Images\1756818093320653.jpeg')

# %%
image2
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=816x1456>

# %%
ani2_array = np.asarray(image2)

# %%
ani2_array
# Out:
# array([[[120, 140, 165],
#         [120, 140, 165],
#         [120, 140, 165],
#         ...,
#         [119, 139, 163],
#         [119, 139, 163],
#         [119, 139, 163]],
#
#        [[120, 140, 165],
#         [120, 140, 165],
#         [120, 140, 165],
#         ...,
#         [119, 139, 163],
#         [119, 139, 163],
#         [119, 139, 163]],
#
#        [[120, 140, 165],
#         [120, 140, 165],
#         [120, 140, 165],
#         ...,
#         [120, 140, 164],
#         [120, 140, 164],
#         [120, 140, 164]],
#
#        ...,
#
#        [[ 77,  85,  87],
#         [ 53,  61,  63],
#         [ 36,  44,  47],
#         ...,
#         [ 51,  62,  66],
#         [ 50,  61,  65],
#         [ 50,  61,  65]],
#
#        [[ 75,  83,  85],
#         [ 60,  68,  70],
#         [ 45,  53,  55],
#         ...,
#         [ 50,  61,  65],
#         [ 50,  61,  65],
#         [ 50,  61,  65]],
#
#        [[ 77,  85,  87],
#         [ 75,  83,  85],
#         [ 62,  70,  72],
# ...

# %%
plt.imshow(image2)
plt.show()
